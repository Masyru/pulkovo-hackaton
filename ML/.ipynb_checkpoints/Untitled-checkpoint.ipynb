# %%
import pandas as pd
import numpy as np
import re

# %%
dfs = pd.read_excel('data/Приложение №2.xlsx', sheet_name=None)

# PROGRAMS
programs_params = dfs['параметры программ'].iloc[:, 1:]
programs_params.columns = ['discipline', 'program', 'features', 'academic_hours', 
                           'hours_in_class', 'practical_hours', 'hours_in_SDO', 
                           'face2face_days', 'groups_count_now', 'BBCC_workers_count_now', 
                           'outside_listeners_could_be_learnt', 'teachers_now', 'rooms_count']
prev = None
tmp_disc = []
for el in programs_params['discipline']:
    if not el is np.nan:
        prev = el
        tmp_disc.append(el)
    else:
        tmp_disc.append(prev)
programs_params['discipline'] = tmp_disc
programs_params['discipline'] = programs_params['discipline'].apply(lambda x: x.replace('\n', ''))
programs_params['features'] = programs_params['features'].fillna('нет').apply(lambda x: x.lower())
programs_params[['practical_hours', 'hours_in_SDO']] = programs_params[['practical_hours', 'hours_in_SDO']].astype(str).apply(lambda x: x.apply(lambda y: y.strip()), axis=0)
programs_params = programs_params.loc[programs_params.iloc[:, :7].dropna().index].reset_index(drop=True)
programs_params = programs_params.replace('-', 0).fillna(0)
programs_params[['practical_hours', 'hours_in_SDO']] = programs_params[['practical_hours', 'hours_in_SDO']].astype(float)
programs_params.iloc[:, -6:] = programs_params.iloc[:, -6:].astype(int)

# ROOMS
rooms_params = dfs['параметры аудиторий']
rooms_params.iloc[:, 2:] = rooms_params.iloc[:, 2:].apply(lambda x: x.apply(lambda y: ' '.join(y.replace('\n', ' ').split())), axis=0)
rooms_params['Вид занятий'] = rooms_params['Вид занятий'].apply(lambda x: x.split('/'))
rooms_params['Конфигурация аудитории'] = rooms_params['Конфигурация аудитории'].apply(lambda x: 'без парт' if 'стулья без парт, для тренинговых форматов' in ' '.join(x.split()) else x).apply(lambda x: x.split(','))
rooms_params['config'] = rooms_params['Вид занятий'] + rooms_params['Конфигурация аудитории']
rooms_params = rooms_params.drop(['Вид занятий', 'Конфигурация аудитории'], axis=1)
rooms_params.columns = ['room', 'capacity', 'advantage4', 'available4', 'config']
rooms_params['room'] = rooms_params['room'].astype(str).apply(lambda x: ''.join(x.split()).lower())

# TEACHERS
teachers_params = dfs['параметры преподавателей']

# %%
def fucking_terms(x):
    shortcuts = {
        'ПОЗ ВС': 'Противообледенительная защита ВС'
    }
    x = x.replace('\n', '')
    if 'кроме' in x:
        tmp = ' '.join(x.replace('кроме', '').strip().split())
        tmp = shortcuts[tmp] if tmp in shortcuts.keys() else tmp 
        return [el for el in programs_params['discipline'].unique() if el != tmp]
    
    elif 'все дисциплины' in ' '.join(x.split()):
        return programs_params['discipline'].unique()
    
    out = []
    for el in x.split(';'):
        el = ' '.join(el.split())
        if 'програм' in x:
            tmp = []
            splitted = x.split()
            flag = False
            flag1 = False
            for el in splitted:
                if 'програм' in el:
                    flag = True
                    continue

                if flag1:
                    tmp.append('П'+re.findall(r'\d+', el)[0])
                    break

                if flag:
                    if el == 'и':
                        flag1 = True
                        continue
                    tmp.append('П'+re.findall(r'\d+', el)[0])
            name = x.split(',')[0]
            name = shortcuts[name] if name in shortcuts.keys() else name 

            out += [name] + tmp
        else:
            out += el
    
    return out
# Out:
#   File "<ipython-input-160-cee259aa2c20>", line 14
#     for el in x.split(';')
#                           ^
# SyntaxError: invalid syntax

# %%
re.findall(r'\d+', '#10')
# Out:
# ['10']

# %%
rooms_params['available4'] = rooms_params['available4'].apply(lambda x: [el for el in programs_params['discipline'].unique() if el != ' '.join(x.replace('кроме', '').strip().split())] if 'кроме' in x else x)
rooms_params['available4'] = rooms_params['available4'].apply(lambda x: x if type(x) == list else (programs_params['discipline'].unique() if 'все дисциплины' in ' '.join(x.split()) else x))

# %%
rooms_params.iloc[7]
# Out:
# room                                                       3091
# capacity                                                     20
# advantage4                                                  нет
# available4    Авиационная безопасность, только для практичес...
# config        [практические, с партами,  муляжи для Авиацион...
# Name: 7, dtype: object

# %%
rooms_params['available4']
# Out:
# 'Авиационная безопасность, только для практических занятий по программам №30, 31 и 32'

# %%
rooms_params
# Out:
#         room  capacity                          advantage4  \
# 0        105        18            Авиационная безопасность
# 1        106        20            Авиационная безопасность
# 2        107        24            Авиационная безопасность
# 3       414б        24       Центровка и контроль загрузки
# 4     414б-1        32                                 нет
# 5     416а,б        18            Авиационная безопасность
# 6        422        18                                 нет
# 7       3091        20                                 нет
# 8       гасс        20                                 нет
# 9    иас,202        20  Организация наземного обслуживания
# 10  бато,213        18                            Водители
#
#                                            available4  \
# 0   [Центровка и контроль загрузки, Управление без...
# 1   [Центровка и контроль загрузки, Управление без...
# 2   [Центровка и контроль загрузки, Управление без...
# 3   [Центровка и контроль загрузки, Управление без...
# 4   [Центровка и контроль загрузки, Управление без...
# 5   [Центровка и контроль загрузки, Управление без...
# 6   [Центровка и контроль загрузки, Управление без...
# 7   Авиационная безопасность, только для практичес...
# 8           Аварийно-спасательное обеспечение полетов
# 9   Организация наземного обслуживания; Центровка ...
# 10                                   Водители; ПОЗ ВС
#
#                                                config
# 0                          [теоретические, с партами]
# 1                          [теоретические, с партами]
# 2            [практические, теоретические, с партами]
# 3    [теоретические, с партами,  интерактивная доска]
# 4             [теоретические, практические, без парт]
# 5             [практические, теоретические, без парт]
# 6                          [теоретические, с партами]
# 7   [практические, с партами,  муляжи для Авиацион...
# 8            [практические, теоретические, с партами]
# 9                          [теоретические, с партами]
# 10                         [теоретические, с партами]

# %%
programs_params
# Out:
#                                    discipline  \
# 0               Центровка и контроль загрузки
# 1               Центровка и контроль загрузки
# 2            Управление безопасностью полетов
# 3            Управление безопасностью полетов
# 4               Подготовка преподавателей АУЦ
# 5               Подготовка преподавателей АУЦ
# 6                               Опасные грузы
# 7                               Опасные грузы
# 8                               Опасные грузы
# 9                               Опасные грузы
# 10                              Опасные грузы
# 11                              Опасные грузы
# 12          Организацияпассажирских перевозок
# 13          Организацияпассажирских перевозок
# 14         Организация наземного обслуживания
# 15         Организация наземного обслуживания
# 16           Противообледенительная защита ВС
# 17           Противообледенительная защита ВС
# 18           Противообледенительная защита ВС
# 19           Противообледенительная защита ВС
# 20                                   Водители
# 21                                   Водители
# 22                                   Водители
# 23                                   Водители
# 24                                   Водители
# 25                                   Водители
# 26                                   Водители
# 27                                   Водители
# 28                   Авиационная безопасность
# 29                   Авиационная безопасность
# 30                   Авиационная безопасность
# 31                   Авиационная безопасность
# 32                   Авиационная безопасность
# 33                   Авиационная безопасность
# 34                   Авиационная безопасность
# 35                   Авиационная безопасность
# 36                   Авиационная безопасность
# 37                   Авиационная безопасность
# 38  Аварийно-спасательное обеспечение полетов
#
#                                               program  \
# 0    Программа повышения квалификации "Центровка и...
# 1   Программа повышения квалификации "Центровка и ...
# 2   Программа повышения квалификации государственн...
# 3   Программа повышения квалификации  руководящего...
# 4   Программа повышения квалификации «Базовые комп...
# 5   Программа повышения квалификации «Подготовка п...
# 6   Программа повышения квалификации «Перевозка оп...
# 7   Программа повышения квалификации «Перевозка оп...
# 8   Программа повышения квалификации «Перевозка оп...
# 9   Программа повышения квалификации «Перевозка оп...
# 10  Программа повышения квалификации «Перевозка оп...
# 11  Программа повышения квалификации «Перевозка оп...
# 12  Программа повышения квалификации «Организация ...
# 13  Программа повышения квалификации «Организация ...
# 14  Программа повышения квалификации «Организация ...
# 15  Программа повышения квалификации «Организация ...
# 16  Программа повышения квалификации "Обеспечение ...
# 17  Программа повышения квалификации "Обеспечение ...
# 18  Программа повышения квалификации "Организация ...
# 19  Программа повышения квалификации "Организация ...
# 20  Программа начальной подготовки водителей спецт...
# 21  Программа дополнительной подготовки водителей ...
# 22  Программа начальной подготовки водителей спецт...
# 23  Программа дополнительной подготовки водителей ...
# 24  Программа начальной подготовки водителей спецт...
# 25  Программа дополнительной подготовки водителей ...
# 26  Программа начальной подготовки руководителей п...
# 27  Программа дополнительной подготовки руководите...
# 28  Программа начальной подготовки «Предполётный д...
# 29  Программа специальной профессиональной подгото...
# 30  Программа повышения квалификации «Предполётный...
# 31  Программа начальной подготовки «Перронный конт...
# 32  Программа специальной профессиональной подгото...
# 33  Программа повышения квалификации «Перронный ко...
# 34  Программа начальной подготовки «Предотвращение...
# 35  Программа специальной профессиональной подгото...
# 36  Программа повышения квалификации «Предотвращен...
# 37  Программа повышения квалификации «Перевозка оп...
# 38          Аварийно-спасательное обеспечение полетов
#
#                                              features  academic_hours  \
# 0                       требуется интерактивная доска            80.0
# 1                       требуется интерактивная доска            64.0
# 2   желательно все дни в одной и той же аудитории,...            40.0
# 3       желательно все дни в одной и той же аудитории            40.0
# 4    необходима аудитория  без парт: 414б-1 или 416аб            24.0
# 5    необходима аудитория  без парт: 414б-1 или 416аб            16.0
# 6                                                 нет            24.0
# 7                                                 нет            16.0
# 8                                                 нет            16.0
# 9                                                 нет            16.0
# 10                                                нет            24.0
# 11                                                нет            16.0
# 12                                                нет            16.0
# 13                                                нет            32.0
# 14                                    желателен  414б            72.0
# 15                                     желателен 414б            32.0
# 16  на практические занятия необходима аудитория б...            16.0
# 17                                                нет            16.0
# 18                                                нет            16.0
# 19                                                нет            16.0
# 20                                 аудитория бато,213            33.0
# 21                                 аудитория бато,213            27.0
# 22                                 аудитория бато,213            74.0
# 23                                 аудитория бато,213            67.0
# 24                                 аудитория бато,213            74.0
# 25                                 аудитория бато,213            67.0
# 26                                 аудитория бато,213            29.5
# 27                                 аудитория бато,213            25.5
# 28                              аудитория 105,106,107           144.0
# 29                              аудитория 105,106,107            82.0
# 30                              аудитория 105,106,107            42.0
# 31                              аудитория 105,106,107           144.0
# 32                              аудитория 105,106,107            82.0
# 33                              аудитория 105,106,107            42.0
# 34                              аудитория 105,106,107           144.0
# 35                              аудитория 105,106,107            82.0
# 36                              аудитория 105,106,107            42.0
# 37                                                нет            16.0
# 38                                               гасс           136.0
#
#    hours_in_class  practical_hours  hours_in_SDO  face2face_days  \
# 0             80               0.0           0.0              10
# 1              64              0.0           0.0               8
# 2              40              0.0           0.0               5
# 3             40               0.0           0.0               5
# 4              24              0.0           0.0               3
# 5             16               0.0           0.0               2
# 6              24              0.0           0.0               3
# 7             16               0.0           0.0               2
# 8              16              0.0           0.0               2
# 9               8              0.0           8.0               2
# 10             16              0.0           8.0               3
# 11             8               0.0           8.0               2
# 12             16              0.0           0.0               2
# 13             26              6.0           0.0               4
# 14             24              0.0          48.0               3
# 15             16              0.0          16.0               2
# 16              8              8.0           0.0               2
# 17              4              4.0           8.0               1
# 18              8              8.0           0.0               2
# 19              8              0.0           8.0               1
# 20              7             24.0           0.0               1
# 21              1             24.0           2.0               1
# 22              8             64.0           0.0               2
# 23              1             64.0           2.0               1
# 24              8             64.0           0.0               2
# 25              1             64.0           2.0               1
# 26              4             25.5           0.0               1
# 27              0             25.5           2.0               0
# 28             24            120.0           0.0              23
# 29             28             28.0          26.0               7
# 30             16              0.0          26.0               2
# 31             24            120.0           0.0              23
# 32             28             28.0          26.0               7
# 33             16              0.0          26.0               2
# 34             24            120.0           0.0              23
# 35             28             28.0          26.0               7
# 36             16              0.0          26.0               2
# 37              8              0.0           8.0               1
# 38             24            120.0           0.0              30
#
#     groups_count_now  BBCC_workers_count_now  \
# 0                  1                      20
# 1                  1                      17
# 2                  0                       0
# 3                  6                      44
# 4                  1                       5
# 5                  1                      10
# 6                  1                      20
# 7                  5                      88
# 8                  4                      50
# 9                  6                     124
# 10                 2                      30
# 11                 6                      72
# 12                 4                      48
# 13                 2                      20
# 14                 2                      52
# 15                 6                     152
# 16                 1                      10
# 17                 5                      54
# 18                 6                      60
# 19                13                     250
# 20                 0                       0
# 21                 0                       0
# 22                 0                       0
# 23                 0                       0
# 24                 0                       0
# 25                 0                       0
# 26                 0                       0
# 27                 0                       0
# 28                18                     414
# 29                18                     414
# 30                22                     300
# 31                 4                      40
# 32                 2                      40
# 33                 9                      94
# 34                 1                      15
# 35                 2                      15
# 36                 6                      86
# 37                25                     472
# 38                 2                      64
#
#     outside_listeners_could_be_learnt  teachers_now  rooms_count
# 0                                   4             2            6
# 1                                   7             2            6
# 2                                   0             4            7
# 3                                 100             4            7
# 4                                  19             1            2
# 5                                  14             1            2
# 6                                   4             2            7
# 7                                  32             2            7
# 8                                  46             2            7
# 9                                  20             2            7
# 10                                 18             2            7
# 11                                 72             2            7
# 12                                 48             3            7
# 13                                 28             3            7
# 14                                 -4             4            7
# 15                                 -8             4            7
# 16                                  5             6            8
# 17                                 21             6            8
# 18                                 30             6            8
# 19                                -55             6            8
# 20                                  0             2            1
# 21                                  0             2            1
# 22                                  0             2            1
# 23                                  0             2            1
# 24                                  0             2            1
# 25                                  0             2            1
# 26                                  0             2            1
# 27                                  0             2            1
# 28                                  0             8            4
# 29                                  0             8            3
# 30                                  0             8            3
# 31                                  0            10            3
# 32                                  0            10            3
# 33                                  0            10            3
# 34                                  0            10            3
# 35                                  0            10            3
# 36                                  0            10            3
# 37                                103             2            7
# 38                                  0             4            1
